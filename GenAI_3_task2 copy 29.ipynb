# %% [markdown]
# # **VAE Architecture**

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# ----------------------------
# Encoder Network
# ----------------------------
class Encoder(nn.Module):
    def __init__(self, latent_dim):
        super(Encoder, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=4, stride=2, padding=1),  # 28x28 -> 14x14
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1), # 14x14 -> 7x7
            nn.ReLU()
        )
        self.flatten = nn.Flatten()
        self.fc_mu = nn.Linear(64 * 7 * 7, latent_dim)
        self.fc_logvar = nn.Linear(64 * 7 * 7, latent_dim)

    def forward(self, x):
        x = self.conv(x)
        x = self.flatten(x)
        mu = self.fc_mu(x)
        logvar = self.fc_logvar(x)
        return mu, logvar

# ----------------------------
# Decoder Network (Using Beta)
# ----------------------------
class Decoder(nn.Module):
    def __init__(self, latent_dim):
        super(Decoder, self).__init__()
        self.fc = nn.Linear(latent_dim, 32 * 7 * 7)  # Smaller hidden rep

        self.deconv_base = nn.Sequential(
            nn.ConvTranspose2d(32, 16, kernel_size=4, stride=2, padding=1),  # 7x7 -> 14x14
            nn.ReLU(),
            nn.ConvTranspose2d(16, 8, kernel_size=4, stride=2, padding=1),   # 14x14 -> 28x28
            nn.ReLU()
        )

        self.alpha_head = nn.Conv2d(8, 1, kernel_size=3, padding=1)
        self.beta_head = nn.Conv2d(8, 1, kernel_size=3, padding=1)

    def forward(self, z):
        x = self.fc(z).view(-1, 32, 7, 7)
        x = self.deconv_base(x)
        alpha = F.softplus(self.alpha_head(x)) + 1e-3
        beta = F.softplus(self.beta_head(x)) + 1e-3
        return alpha, beta

# ----------------------------
# VAE Wrapper
# ----------------------------
class VAE(nn.Module):
    def __init__(self, latent_dim=20):
        super(VAE, self).__init__()
        self.encoder = Encoder(latent_dim)
        self.decoder = Decoder(latent_dim)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x):
        mu_z, logvar_z = self.encoder(x)
        z = self.reparameterize(mu_z, logvar_z)
        alpha, beta = self.decoder(z)
        return alpha, beta, mu_z, logvar_z, z

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt
import torchvision.utils as vutils

def get_mnist_dataloaders(batch_size=128):
    def transform_fn(x):
        x = transforms.ToTensor()(x)
        return (x * 0.98 + 0.01)  # now in [0.01, 0.99]
    
    full_train_set = datasets.MNIST('./data', train=True, download=True, transform=transform_fn)
    test_set = datasets.MNIST('./data', train=False, download=True, transform=transform_fn)
    train_set, val_set = random_split(full_train_set, [50000, 10000])
    return (
        DataLoader(train_set, batch_size=batch_size, shuffle=True),
        DataLoader(val_set, batch_size=batch_size, shuffle=False),
        DataLoader(test_set, batch_size=batch_size, shuffle=False)
    )

def elbo_loss(x, alpha, beta, mu_z, logvar_z, beta_kl):
    B = x.size(0)
    x = x.view(B, -1)
    alpha = alpha.view(B, -1)
    beta = beta.view(B, -1)

    eps = 1e-6
    x = torch.clamp(x, eps, 1 - eps)

    log_likelihood = (
        torch.lgamma(alpha + beta)
        - torch.lgamma(alpha)
        - torch.lgamma(beta)
        + (alpha - 1) * torch.log(x)
        + (beta - 1) * torch.log(1 - x)
    )
    recon_loss = -torch.sum(log_likelihood, dim=1)

    kl_div = -0.5 * torch.sum(1 + logvar_z - mu_z.pow(2) - logvar_z.exp(), dim=1)

    return torch.mean(recon_loss + beta_kl * kl_div)

# %%
import torch
import matplotlib.pyplot as plt

def train_vae(model, train_loader, val_loader, optimizer,
                                   num_epochs=100, patience=10, device='cuda'):

    model = model.to(device)
    train_elbo, val_elbo = [], []

    best_val_elbo = float('-inf')
    epochs_without_improvement = 0

    for epoch in range(1, num_epochs + 1):
        #beta_kl = min(10.0, epoch / 50 * 10)
        beta_kl = 10

        model.train()
        total_train_loss = 0
        for x_batch, _ in train_loader:
            x_batch = x_batch.to(device)
            optimizer.zero_grad()
            mu_x, logvar_x, mu_z, logvar_z, _ = model(x_batch)
            loss = elbo_loss(x_batch, mu_x, logvar_x, mu_z, logvar_z, beta_kl)
            loss.backward()
            optimizer.step()
            total_train_loss += loss.item()

        avg_train_loss = total_train_loss / len(train_loader)
        train_elbo.append(-avg_train_loss)

        # --- Validation ---
        model.eval()
        total_val_loss = 0
        with torch.no_grad():
            for x_val, _ in val_loader:
                x_val = x_val.to(device)
                mu_x, logvar_x, mu_z, logvar_z, _ = model(x_val)
                loss = elbo_loss(x_val, mu_x, logvar_x, mu_z, logvar_z, beta_kl)
                total_val_loss += loss.item()

        avg_val_loss = total_val_loss / len(val_loader)
        val_elbo.append(-avg_val_loss)
        

        print(f"Epoch {epoch:02d} | Train ELBO: {-avg_train_loss:.4f} | Val ELBO: {-avg_val_loss:.4f}")

        # Early stopping logic
        if -avg_val_loss > best_val_elbo:
            best_val_elbo = -avg_val_loss
            epochs_without_improvement = 0
            best_model_state = model.state_dict()
        else:
            epochs_without_improvement += 1

        if epochs_without_improvement >= patience:
            print(f"Stopping early at epoch {epoch} due to no improvement in validation ELBO.")
            break

    # Restore best model
    model.load_state_dict(best_model_state)

    # Plot ELBO
    plt.plot(train_elbo, label='Train ELBO')
    plt.plot(val_elbo, label='Validation ELBO')
    plt.xlabel('Epoch')
    plt.ylabel('ELBO')
    plt.legend()
    plt.title('ELBO vs Epoch')
    plt.show()

    return train_elbo, val_elbo

# %%
import torchvision.utils as vutils

def test_vae_reconstruction_and_generation(model, test_loader, device='cuda'):
    model.eval()
    model = model.to(device)

    # Get a single batch from test set
    x_test, _ = next(iter(test_loader))
    x_test = x_test[:32].to(device)  # use only first 32 for display
    with torch.no_grad():
        mu_z, logvar_z = model.encoder(x_test)
        z = model.reparameterize(mu_z, logvar_z)
        alpha, beta = model.decoder(z)
        alpha = torch.clamp(alpha, min=1e-3)
        beta = torch.clamp(beta, min=1e-3)
        recon_x = torch.distributions.Beta(alpha, beta).sample()

    # Arrange originals and reconstructions side-by-side
    grid = torch.cat([x_test.cpu(), recon_x.cpu()], dim=0)
    grid_img = vutils.make_grid(grid, nrow=8, pad_value=1)

    plt.figure(figsize=(8, 8))
    plt.axis('off')
    plt.title('Top: Original | Bottom: Reconstruction')
    plt.imshow(grid_img.permute(1, 2, 0), cmap='gray')
    plt.show()

def generate_from_prior(model, num_samples=64, device='cuda'):
    model.eval()
    model = model.to(device)

    with torch.no_grad():
        z = torch.randn(num_samples, model.encoder.fc_mu.out_features).to(device)
        alpha, beta = model.decoder(z)
        # alpha = torch.clamp(alpha, min=1e-3)
        # beta = torch.clamp(beta, min=1e-3)
        gen_x = torch.distributions.Beta(alpha, beta).sample()


    grid_img = vutils.make_grid(gen_x.cpu(), nrow=8, pad_value=1)

    plt.figure(figsize=(8, 8))
    plt.axis('off')
    plt.title('Generated Samples from Prior')
    plt.imshow(grid_img.permute(1, 2, 0), cmap='gray')
    plt.show()

# %%
torch.manual_seed(42)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
latent_dim = 25
batch_size = 128

train_loader, val_loader, test_loader = get_mnist_dataloaders(batch_size)

model = VAE(latent_dim)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

train_vae(model, train_loader, val_loader, optimizer, num_epochs=300, patience=10, device=device)
test_vae_reconstruction_and_generation(model, test_loader, device=device)
generate_from_prior(model, num_samples=64, device=device)
# Out:
# Epoch 01 | Train ELBO: 1683.2978 | Val ELBO: 2388.1723
# Epoch 02 | Train ELBO: 2629.0243 | Val ELBO: 2820.2684
# Epoch 03 | Train ELBO: 2938.2453 | Val ELBO: 3010.4580
# Epoch 04 | Train ELBO: 3128.4434 | Val ELBO: 3214.1472
# Epoch 05 | Train ELBO: 3264.2571 | Val ELBO: 3339.3185
# Epoch 06 | Train ELBO: 3380.2430 | Val ELBO: 3437.9165
# Epoch 07 | Train ELBO: 3459.3575 | Val ELBO: 3518.1344
# Epoch 08 | Train ELBO: 3537.1768 | Val ELBO: 3567.8700
# Epoch 09 | Train ELBO: 3601.5846 | Val ELBO: 3643.0406
# Epoch 10 | Train ELBO: 3655.7759 | Val ELBO: 3684.7996
# Epoch 11 | Train ELBO: 3701.6326 | Val ELBO: 3712.3909
# Epoch 12 | Train ELBO: 3743.6063 | Val ELBO: 3763.7324
# Epoch 13 | Train ELBO: 3774.5437 | Val ELBO: 3809.2280
# Epoch 14 | Train ELBO: 3814.4864 | Val ELBO: 3823.4153
# Epoch 15 | Train ELBO: 3843.3753 | Val ELBO: 3862.9498
# Epoch 16 | Train ELBO: 3871.8750 | Val ELBO: 3897.5120
# Epoch 17 | Train ELBO: 3885.3117 | Val ELBO: 3901.4586
# Epoch 18 | Train ELBO: 3900.2903 | Val ELBO: 3918.4801
# Epoch 19 | Train ELBO: 3939.6077 | Val ELBO: 3938.1539
# Epoch 20 | Train ELBO: 3944.6404 | Val ELBO: 3975.0721
# Epoch 21 | Train ELBO: 3968.0552 | Val ELBO: 3972.2777
# Epoch 22 | Train ELBO: 3979.1725 | Val ELBO: 3998.8767
# Epoch 23 | Train ELBO: 3995.2033 | Val ELBO: 4006.6734
# Epoch 24 | Train ELBO: 4007.1531 | Val ELBO: 4039.0795
# Epoch 25 | Train ELBO: 4011.9175 | Val ELBO: 4002.3057
# Epoch 26 | Train ELBO: 4023.2873 | Val ELBO: 4048.6063
# Epoch 27 | Train ELBO: 4043.6614 | Val ELBO: 4058.5511
# Epoch 28 | Train ELBO: 4055.3896 | Val ELBO: 4066.5289
# Epoch 29 | Train ELBO: 4066.1239 | Val ELBO: 4085.3584
# Epoch 30 | Train ELBO: 4064.4552 | Val ELBO: 4084.7897
# Epoch 31 | Train ELBO: 4063.6423 | Val ELBO: 4095.0642
# Epoch 32 | Train ELBO: 4092.9135 | Val ELBO: 4103.2475
# Epoch 33 | Train ELBO: 4094.9983 | Val ELBO: 4104.9733
# Epoch 34 | Train ELBO: 4104.8201 | Val ELBO: 4135.0939
# Epoch 35 | Train ELBO: 4096.1107 | Val ELBO: 4113.3388
# Epoch 36 | Train ELBO: 4069.1278 | Val ELBO: 4125.0552
# Epoch 37 | Train ELBO: 4127.5371 | Val ELBO: 4135.1057
# Epoch 38 | Train ELBO: 4132.2344 | Val ELBO: 4128.6492
# Epoch 39 | Train ELBO: 4131.6044 | Val ELBO: 4142.8216
# Epoch 40 | Train ELBO: 4137.3218 | Val ELBO: 4162.1471
# Epoch 41 | Train ELBO: 4107.0976 | Val ELBO: 4153.7007
# Epoch 42 | Train ELBO: 4157.0550 | Val ELBO: 4059.2450
# Epoch 43 | Train ELBO: 4119.2912 | Val ELBO: 4132.9520
# Epoch 44 | Train ELBO: 4160.3418 | Val ELBO: 4169.3092
# Epoch 45 | Train ELBO: 4162.1222 | Val ELBO: 4156.7975
# Epoch 46 | Train ELBO: 4168.8581 | Val ELBO: 4177.7456
# Epoch 47 | Train ELBO: 4138.5446 | Val ELBO: 4169.5816
# Epoch 48 | Train ELBO: 4171.2554 | Val ELBO: 4197.8753
# Epoch 49 | Train ELBO: 4179.9690 | Val ELBO: 4188.4304
# Epoch 50 | Train ELBO: 4171.4435 | Val ELBO: 4163.5458
# Epoch 51 | Train ELBO: 4184.9296 | Val ELBO: 4185.5851
# Epoch 52 | Train ELBO: 4185.7294 | Val ELBO: 4196.8940
# Epoch 53 | Train ELBO: 4175.9629 | Val ELBO: 4143.9476
# Epoch 54 | Train ELBO: 4190.6304 | Val ELBO: 4151.4523
# Epoch 55 | Train ELBO: 4202.8841 | Val ELBO: 4211.0741
# Epoch 56 | Train ELBO: 4199.1280 | Val ELBO: 3891.1911
# Epoch 57 | Train ELBO: 4173.4048 | Val ELBO: 3997.0765
# Epoch 58 | Train ELBO: 4208.8733 | Val ELBO: 4219.9936
# Epoch 59 | Train ELBO: 4217.8632 | Val ELBO: 4197.2693
# Epoch 60 | Train ELBO: 4209.4298 | Val ELBO: 4207.5271
# Epoch 61 | Train ELBO: 4209.9831 | Val ELBO: 4228.1025
# Epoch 62 | Train ELBO: 4225.3484 | Val ELBO: 4225.4284
# Epoch 63 | Train ELBO: 4217.3743 | Val ELBO: 3996.2804
# Epoch 64 | Train ELBO: 4194.1478 | Val ELBO: 4218.0424
# Epoch 65 | Train ELBO: 4232.6082 | Val ELBO: 4244.7376
# Epoch 66 | Train ELBO: 4225.3709 | Val ELBO: 4241.1004
# Epoch 67 | Train ELBO: 4233.9886 | Val ELBO: 4240.8549
# Epoch 68 | Train ELBO: 4237.4361 | Val ELBO: 4256.7084
# Epoch 69 | Train ELBO: 4242.8927 | Val ELBO: 4226.9863
# Epoch 70 | Train ELBO: 4233.7839 | Val ELBO: 4253.6774
# Epoch 71 | Train ELBO: 4240.1224 | Val ELBO: 4236.6600
# Epoch 72 | Train ELBO: 4245.7568 | Val ELBO: 4263.9816
# Epoch 73 | Train ELBO: 4249.0482 | Val ELBO: 4264.6788
# Epoch 74 | Train ELBO: 4255.6697 | Val ELBO: 4254.9160
# Epoch 75 | Train ELBO: 4245.2759 | Val ELBO: 4263.9747
# Epoch 76 | Train ELBO: 4260.1547 | Val ELBO: 4274.1748
# Epoch 77 | Train ELBO: 4248.3323 | Val ELBO: 4253.1992
# Epoch 78 | Train ELBO: 4249.2237 | Val ELBO: 4271.6545
# Epoch 79 | Train ELBO: 4274.8091 | Val ELBO: 4265.1123
# Epoch 80 | Train ELBO: 4261.2358 | Val ELBO: 4269.6109
# Epoch 81 | Train ELBO: 4271.9068 | Val ELBO: 4268.0121
# Epoch 82 | Train ELBO: 4246.6805 | Val ELBO: 4261.7109
# Epoch 83 | Train ELBO: 4275.3808 | Val ELBO: 4284.0066
# Epoch 84 | Train ELBO: 4254.6076 | Val ELBO: 4274.4207
# Epoch 85 | Train ELBO: 4268.7786 | Val ELBO: 4279.3019
# Epoch 86 | Train ELBO: 4279.1303 | Val ELBO: 4290.4352
# Epoch 87 | Train ELBO: 4280.2831 | Val ELBO: 4284.1038
# Epoch 88 | Train ELBO: 4277.6506 | Val ELBO: 4184.8036
# Epoch 89 | Train ELBO: 4278.1360 | Val ELBO: 4288.3567
# Epoch 90 | Train ELBO: 4262.7902 | Val ELBO: 4306.7749
# Epoch 91 | Train ELBO: 4284.3935 | Val ELBO: 4294.5908
# Epoch 92 | Train ELBO: 4289.7280 | Val ELBO: 4295.1097
# Epoch 93 | Train ELBO: 4291.9919 | Val ELBO: 4305.4400
# Epoch 94 | Train ELBO: 4289.6569 | Val ELBO: 4299.7047
# Epoch 95 | Train ELBO: 4273.7014 | Val ELBO: 4295.1617
# Epoch 96 | Train ELBO: 4296.4286 | Val ELBO: 4300.4892
# Epoch 97 | Train ELBO: 4268.4008 | Val ELBO: 4300.4546
# Epoch 98 | Train ELBO: 4282.9426 | Val ELBO: 4300.1260
# Epoch 99 | Train ELBO: 4292.3946 | Val ELBO: 4289.3900
# Epoch 100 | Train ELBO: 4299.4244 | Val ELBO: 4314.8682
# Epoch 101 | Train ELBO: 4294.4329 | Val ELBO: 4306.3897
# Epoch 102 | Train ELBO: 4295.4060 | Val ELBO: 4258.3962
# Epoch 103 | Train ELBO: 4308.6744 | Val ELBO: 4257.1114
# Epoch 104 | Train ELBO: 4299.6374 | Val ELBO: 4308.7446
# Epoch 105 | Train ELBO: 4300.1180 | Val ELBO: 4317.6200
# Epoch 106 | Train ELBO: 4300.2962 | Val ELBO: 4322.5907
# Epoch 107 | Train ELBO: 4312.9507 | Val ELBO: 4256.5485
# Epoch 108 | Train ELBO: 4308.6926 | Val ELBO: 4319.4422
# Epoch 109 | Train ELBO: 4286.5226 | Val ELBO: 4312.6099
# Epoch 110 | Train ELBO: 4239.6694 | Val ELBO: 4288.5032
# Epoch 111 | Train ELBO: 4301.3177 | Val ELBO: 4172.0508
# Epoch 112 | Train ELBO: 4302.1861 | Val ELBO: 4313.5901
# Epoch 113 | Train ELBO: 4302.5637 | Val ELBO: 4274.7932
# Epoch 114 | Train ELBO: 4319.4063 | Val ELBO: 4307.8217
# Epoch 115 | Train ELBO: 4312.1081 | Val ELBO: 4324.5700
# Epoch 116 | Train ELBO: 4322.6872 | Val ELBO: 4325.7089
# Epoch 117 | Train ELBO: 4325.4966 | Val ELBO: 4326.9875
# Epoch 118 | Train ELBO: 4304.5296 | Val ELBO: 4311.6216
# Epoch 119 | Train ELBO: 4312.5283 | Val ELBO: 4338.5596
# Epoch 120 | Train ELBO: 4276.1183 | Val ELBO: 4301.6455
# Epoch 121 | Train ELBO: 4328.5938 | Val ELBO: 4333.5330
# Epoch 122 | Train ELBO: 4334.4319 | Val ELBO: 4342.4502
# Epoch 123 | Train ELBO: 4320.0017 | Val ELBO: 4333.2611
# Epoch 124 | Train ELBO: 4325.0590 | Val ELBO: 4331.2521
# Epoch 125 | Train ELBO: 4296.9054 | Val ELBO: 4319.4402
# Epoch 126 | Train ELBO: 4326.1169 | Val ELBO: 4342.5907
# Epoch 127 | Train ELBO: 4324.2835 | Val ELBO: 4341.1190
# Epoch 128 | Train ELBO: 4315.4682 | Val ELBO: 4339.8361
# Epoch 129 | Train ELBO: 4339.9488 | Val ELBO: 4344.3606
# Epoch 130 | Train ELBO: 4325.4118 | Val ELBO: 4335.2533
# Epoch 131 | Train ELBO: 4327.5785 | Val ELBO: 4347.6946
# Epoch 132 | Train ELBO: 4300.7930 | Val ELBO: 4337.7490
# Epoch 133 | Train ELBO: 4329.5805 | Val ELBO: 4285.6402
# Epoch 134 | Train ELBO: 4329.5953 | Val ELBO: 4352.9676
# Epoch 135 | Train ELBO: 4340.9599 | Val ELBO: 4346.2018
# Epoch 136 | Train ELBO: 4334.2189 | Val ELBO: 4359.0340
# Epoch 137 | Train ELBO: 4338.0162 | Val ELBO: 4318.8418
# Epoch 138 | Train ELBO: 4332.3999 | Val ELBO: 4295.4041
# Epoch 139 | Train ELBO: 4341.3579 | Val ELBO: 4343.4075
# Epoch 140 | Train ELBO: 4346.7029 | Val ELBO: 4353.9631
# Epoch 141 | Train ELBO: 4338.7040 | Val ELBO: 4356.0260
# Epoch 142 | Train ELBO: 4309.2787 | Val ELBO: 4335.0779
# Epoch 143 | Train ELBO: 4347.8138 | Val ELBO: 4350.4471
# Epoch 144 | Train ELBO: 4353.9139 | Val ELBO: 4350.0160
# Epoch 145 | Train ELBO: 4351.5808 | Val ELBO: 4337.8717
# Epoch 146 | Train ELBO: 4330.0768 | Val ELBO: 4345.2446
# Stopping early at epoch 146 due to no improvement in validation ELBO.
